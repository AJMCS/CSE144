# %% [markdown]
# # CSE-144-01 - 2025 Winter - HW 1

# %% [markdown]
# ## Instruction
#
# - Submit your assignments onto **Canvas** before the due date. Upload a single `.ipynb` file with all the necessary output.
# - Don't use any magic function from other libraries. You will get **no credit** if a Gradient Descent function from a known library is used when you are asked to implement **Linear Regression** or **Linear Classifcation**.
# - Don't change the input and output structure of pre-defined functions. Only write your code between `YOUR CODE STARTS HERE` and `YOUR CODE ENDS HERE`. You won't get the points if you alter the code outside these two dividing lines. Most coding parts can be finished with about 5-6 lines of codes.
# - Make sure you have installed required packages imported in the first code block.
#
# ## Rubric
#
# The assignment is worth 59pts in total:
# - Data Preprocessing (12pts)
#     - Remove Missing Values (2pts)
#     - Remove outliers (5pts)
#     - Normalization (5pts)
# - Dataset Preparation (11pts)
#     - Build TrainVal/Test Set `test_split` (5pts)
#     - K-fold Cross Validation `train_val_split` (6pts)
# - Linear Regression (26pts)
#     - `mean_square_error_loss` (3pts)
#     - `mse_gradient` (5pts)
#     - Hyper-Parameters Tuning (6pts)
#     - Traininig (10pts)
#         - Translate Dataframe to Numpy (3pts)
#         - Theta Initialization (1pt)
#         - Loss Computation (3pts)
#         - Gradient Descent (3pts)
#     - Evaluation on test set (2pts)

# %%
import random
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from tqdm.notebook import trange

SEED = 42
random.seed(SEED)
np.random.seed(SEED)

# %% [markdown]
# ## Load the dataset

# %%
data_red = pd.read_csv("winequality-red-new.csv")
data_white = pd.read_csv("winequality-white-new.csv")

data_red["wine_type"] = 1
data_white["wine_type"] = 0

data = pd.concat([data_red, data_white], axis=0)

# %% [markdown]
# ### Visualize data

# %%
data.info()
data.hist(figsize=(10, 10))
# Out:
# <class 'pandas.DataFrame'>
# Index: 3199 entries, 0 to 1599
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         3164 non-null   float64
#  1   volatile acidity      3172 non-null   float64
#  2   citric acid           3170 non-null   float64
#  3   residual sugar        3171 non-null   float64
#  4   chlorides             3170 non-null   float64
#  5   free sulfur dioxide   3171 non-null   float64
#  6   total sulfur dioxide  3166 non-null   float64
#  7   density               3179 non-null   float64
#  8   pH                    3175 non-null   float64
#  9   sulphates             3179 non-null   float64
#  10  alcohol               3171 non-null   float64
#  11  quality               3155 non-null   float64
#  12  wine_type             3199 non-null   int64
# dtypes: float64(12), int64(1)
# memory usage: 349.9 KB
# array([[<Axes: title={'center': 'fixed acidity'}>,
#         <Axes: title={'center': 'volatile acidity'}>,
#         <Axes: title={'center': 'citric acid'}>,
#         <Axes: title={'center': 'residual sugar'}>],
#        [<Axes: title={'center': 'chlorides'}>,
#         <Axes: title={'center': 'free sulfur dioxide'}>,
#         <Axes: title={'center': 'total sulfur dioxide'}>,
#         <Axes: title={'center': 'density'}>],
#        [<Axes: title={'center': 'pH'}>,
#         <Axes: title={'center': 'sulphates'}>,
#         <Axes: title={'center': 'alcohol'}>,
#         <Axes: title={'center': 'quality'}>],
#        [<Axes: title={'center': 'wine_type'}>, <Axes: >, <Axes: >,
#         <Axes: >]], dtype=object)

# %% [markdown]
# ## Data Preprocessing (12pts)
# `data.info()` shows that there are some missing values in the dataset. Also, we can see from the histogram that outliers exist for some features. Moreover, the range of different features has a huge gap: from (0, 1), to (0, 300). In the following you need to perform:
# 1. Drop rows that contain NULL values.
# 2. Remove outliers for features in `['chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'sulphates', 'residual sugar']` based on interquantile range.
# 3. Normalize of features using Z-score method.

# %% [markdown]
# ### Remove Missing Values (2pts)
# Drop rows that have NULL values

# %%
# ========== YOUR CODE STARTS HERE ==========
data.dropna(inplace=True)
# ========== YOUR CODE ENDS HERE ============

print(data.shape)
# Out:
# (2872, 13)

# %% [markdown]
# ### Remove Outliers (5pts)
# Remove outliers for features in `['chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'sulphates', 'residual sugar']` based on interquantile range. Here for each feature, we first sort data in an ascending order.
#
# Let q1 and q3 be the data that ranks 25% and 75% respectively. We then let `iqr = q3 - q1`, and
# compute
# ```
# a = q1 - iqr x 1.5
# b = q3 + iqr x 1.5
# ```
# and remove the data out of the range [a, b].
#
# Note: this can be realized with function `pd.DataFrame.quantile()`.

# %%
def remove_outliers(data):
    for feature in ['chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'sulphates', 'residual sugar']:
        # ========== YOUR CODE STARTS HERE ==========
        q1 = data[feature].quantile(0.25)
        q3 = data[feature].quantile(0.75)

        iqr = q3 - q1
        
        a  = q1 - iqr * 1.5
        b = q3 + iqr * 1.5

        data = data[(data[feature] >= a) & (data[feature] <= b)]

        # ========== YOUR CODE ENDS HERE ============

    return data


data_cleaned = remove_outliers(data)
print(data_cleaned.shape)
# Out:
# (2437, 13)

# %% [markdown]
# ### Normalization (5pts)
# Scale all features using z-score normalization.
#
# `quality` is the target for linear regression. Scale the `quality` from `[0, 10]` to `[0, 1]` for easier convergence.
#
# `wine_type` is the target for linear classification. No normalization is needed for `wine_type` as it is already binary.
#
# Note: use different mean and std for different feature.

# %%
# ========== YOUR CODE STARTS HERE ==========
data = data.reset_index(drop=True)

norm_features = [col for col in data.columns if col not in ['quality', 'wine_type']]
data[norm_features] = (data[norm_features] - data[norm_features].mean()) / data[norm_features].std()
data['quality'] = data['quality'] / 10

data_normalized = data
# ========== YOUR CODE ENDS HERE ============

print("Mean\n", data_normalized.mean(axis=0))
print("STD\n", data_normalized.std(axis=0))

assert np.isclose(data_normalized.drop(columns=["quality", "wine_type"]).mean(axis=0), 0).all()
assert np.isclose(data_normalized.drop(columns=["quality", "wine_type"]).std(axis=0), 1).all()
assert data_normalized["wine_type"].apply(lambda x: x in [0, 1]).all()
assert data_normalized["quality"].apply(lambda x: 0 <= x and x <= 1).all()
# Out:
# Mean
#  fixed acidity          -3.958455e-17
# volatile acidity        4.354301e-16
# citric acid            -5.937683e-17
# residual sugar         -3.958455e-17
# chlorides               1.187537e-16
# free sulfur dioxide     3.958455e-17
# total sulfur dioxide    1.583382e-16
# density                -3.443856e-15
# pH                      2.850088e-15
# sulphates              -3.958455e-17
# alcohol                 5.096511e-16
# quality                 5.761838e-01
# wine_type               4.993036e-01
# dtype: float64
# STD
#  fixed acidity           1.000000
# volatile acidity        1.000000
# citric acid             1.000000
# residual sugar          1.000000
# chlorides               1.000000
# free sulfur dioxide     1.000000
# total sulfur dioxide    1.000000
# density                 1.000000
# pH                      1.000000
# sulphates               1.000000
# alcohol                 1.000000
# quality                 0.085507
# wine_type               0.500087
# dtype: float64

# %% [markdown]
# Now we visualize the data again.

# %%
data_normalized.info()
data_normalized.hist(figsize=(10, 10))
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2872 entries, 0 to 2871
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         2872 non-null   float64
#  1   volatile acidity      2872 non-null   float64
#  2   citric acid           2872 non-null   float64
#  3   residual sugar        2872 non-null   float64
#  4   chlorides             2872 non-null   float64
#  5   free sulfur dioxide   2872 non-null   float64
#  6   total sulfur dioxide  2872 non-null   float64
#  7   density               2872 non-null   float64
#  8   pH                    2872 non-null   float64
#  9   sulphates             2872 non-null   float64
#  10  alcohol               2872 non-null   float64
#  11  quality               2872 non-null   float64
#  12  wine_type             2872 non-null   int64
# dtypes: float64(12), int64(1)
# memory usage: 291.8 KB
# array([[<Axes: title={'center': 'fixed acidity'}>,
#         <Axes: title={'center': 'volatile acidity'}>,
#         <Axes: title={'center': 'citric acid'}>,
#         <Axes: title={'center': 'residual sugar'}>],
#        [<Axes: title={'center': 'chlorides'}>,
#         <Axes: title={'center': 'free sulfur dioxide'}>,
#         <Axes: title={'center': 'total sulfur dioxide'}>,
#         <Axes: title={'center': 'density'}>],
#        [<Axes: title={'center': 'pH'}>,
#         <Axes: title={'center': 'sulphates'}>,
#         <Axes: title={'center': 'alcohol'}>,
#         <Axes: title={'center': 'quality'}>],
#        [<Axes: title={'center': 'wine_type'}>, <Axes: >, <Axes: >,
#         <Axes: >]], dtype=object)

# %% [markdown]
# ## Dataset Preparation (11pts)
# Next we will split dataset to train set, validation set and test set. First we randomly choose 20% as test set. Then we use $k$-fold validation on the remaining 80% to generate $k$ different train set and validation set pairs, where $k=5$.

# %%
# 5pts
def test_split(data, test_ratio=0.2, seed=SEED):
    '''
    Use function `train_test_split` to split test set.
    '''
    # ========== YOUR CODE STARTS HERE ==========
    features = [col for col in data.columns if col not in ['quality']]
    x_train_val, x_test, y_train_val, y_test = train_test_split(data[features], data[['quality']], test_size=0.2, random_state=seed)
    

    # ========== YOUR CODE ENDS HERE ============

    return (x_train_val.reset_index(drop=True),
            y_train_val.reset_index(drop=True),
            x_test.reset_index(drop=True),
            y_test.reset_index(drop=True))


# 6pts
def train_val_split(x_train_val, y_train_val, k=5):
    '''
    Use given index sets to generate k train and validation pairs. The return value should be
    a list whose components are tuples:
    [(x_train1, y_train1, x_val1, y_val1), ..., (x_traink, y_traink, x_valk, y_valk)]

    Each x_traink/y_traink/x_valk/y_valk is a pd.DataFrame

    '''
    index_shuffle = list(x_train_val.index)
    random.shuffle(index_shuffle)

    # This is the indices for the validation set for each fold
    val_indices_list = [
        [
            index_shuffle[i + fold_i]
            for i in range(0, len(index_shuffle), k) if i + fold_i < len(index_shuffle)
        ]
        for fold_i in range(k)
    ]

    train_val_list = []
    # ========== YOUR CODE STARTS HERE ==========
    for fold_i in range(k):
        val_idx = val_indices_list[fold_i]
        train_idx = [idx for idx in index_shuffle if idx not in val_indices_list[fold_i]]
        
        x_train_k = x_train_val.loc[train_idx].reset_index(drop=True)
        y_train_k = y_train_val.loc[train_idx].reset_index(drop=True)
        x_val_k = x_train_val.loc[val_idx].reset_index(drop=True)
        y_val_k = y_train_val.loc[val_idx].reset_index(drop=True)
        
        train_val_list.append((x_train_k, y_train_k, x_val_k, y_val_k))
    # ========== YOUR CODE ENDS HERE ============
    return train_val_list


K = 5
x_train_val, y_train_val, x_test, y_test = test_split(data_normalized, test_ratio=0.2)
train_val_list = train_val_split(x_train_val, y_train_val, k=K)
print(train_val_list)

assert len(train_val_list) == K and {len(fold) for fold in train_val_list} == {4}
# Out:
# [(      fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0         -1.010941         -0.582475     0.645714        1.564600  -0.442967
# 1         -0.041680          0.618698     0.585377       -0.542284  -0.163726
# 2         -1.010941         -0.321351     2.154115        2.814031  -0.489508
# 3         -0.687854         -0.582475    -0.017983        1.160372  -0.373157
# 4          1.379903          1.506522     0.102689       -0.468788   0.487838
# ...             ...               ...          ...             ...        ...
# 1832       0.475260          1.297622    -1.224704       -0.370794   0.511109
# 1833       0.022938         -1.209174    -0.198991        0.045683  -0.396427
# 1834      -0.106297         -0.216901    -0.017983       -0.640279   0.162056
# 1835      -1.592497         -0.478025    -0.017983       -0.860767  -0.698939
# 1836      -1.075558         -0.425800    -0.138655        0.070182  -0.652399
#
#       free sulfur dioxide  total sulfur dioxide   density        pH  \
# 0
#
#       free sulfur dioxide  total sulfur dioxide   density        pH  \
# 0               -0.605294              1.184150 -0.946536  0.003451
# 1               -0.777322             -1.206130 -0.218197  0.063891
# 2                0.025477              1.184150  0.910015 -0.661382
# 3               -0.031866              1.217348 -0.700186 -0.056988
# 4               -1.293407             -1.355522 -0.560945  2.783663
# ...                   ...                   ...       ...       ...
# 1832            -1.064036             -0.724754  0.652954  0.607845
# 1833            -0.146552              0.088605 -0.403852 -1.024018
# 1834            -0.490608             -1.139733 -0.414563 -0.056988
# 1835             0.140162              0.984960 -1.196456  1.756194
# 1836             1.114990              1.034757  0.970710 -1.870170
#
#       sulphates   alcohol  wine_type
# 0      0.339102  0.463986          0
# 1      0.399334  1.158935          1
# 2     -0.443922 -1.447124          0
# 3     -0.082526  0.768026          0
# 4      0.339102  2.027621          1
# ...         ...       ...        ...
# 1832   0.640265 -0.144094          1
# 1833  -0.624619 -0.839043          0
# 1834   0.760730  0.811460          1
# 1835  -0.082526 -0.317832          0
# 1836  -0.986015 -1.447124          0
#
# [1837 rows x 12 columns],       quality
# 0         0.5
# 1         0.6
# 2         0.6
# 3         0.6
# 4         0.7
# ...       ...
# 1832      0.5
# 1833      0.6
# 1834      0.8
# 1835      0.6
# 1836      0.8
#
# [1837 rows x 1 columns],      fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0        -1.010941         -0.582475     0.645714        1.564600  -0.442967
# 1         1.379903          1.506522     0.102689       -0.468788   0.487838
# 2        -0.170914          0.462023    -1.224704       -0.444290   0.022436
# 3        -1.269410         -0.582475    -1.526385       -0.885265  -0.675669
# 4        -0.817088         -0.530250     3.662517        0.927635  -0.768749
# ..             ...               ...          ...             ...        ...
# 455       1.250668         -0.060226     0.645714        1.099125   0.045706
# 456       0.022938          2.864370    -1.647057       -0.591282   0.534379
# 457      -0.752471          0.879823    -1.707393       -0.640279  -0.000835
# 458       0.475260          1.297622    -1.224704       -0.370794   0.511109
# 459      -1.075558         -0.425800    -0.138655        0.070182  -0.652399
#
#      free sulfur dioxide  total sulfur dioxide   density        pH  sulphates  \
# 0               1.688418              0.935162 -0.589507 -0.963579   0.098172
# 1              -0.203894             -0.027589  0.910015  0.245209   0.278869
# 2              -1.236065             -1.305725  0.095989  0.305648  -0.624619
# 3              -0.834665             -1.040138 -1.053645  0.668285  -1.347410
# 4               1.401704              1.765120 -0.503820  0.849603  -0.504154
# ..                   ...                   ...       ...       ...        ...
# 455            -0.433266             -0.890746  1.156365  0.245209   1.423288
# 456            -1.064036             -1.206130  0.195957 -0.298746  -0.082526
# 457            -1.236065             -1.355522  0.588689  1.272678   0.640265
# 458            -0.490608             -0.874146  0.956429  0.245209  -0.142759
# 459             0.484219              0.022208 -2.039045 -0.177867  -0.022294
#
#       alcohol  wine_type
# 0    0.463986          0
# 1   -0.317832          1
# 2    0.029643          1
# 3   -1.099649          0
# 4    1.072066          0
# ..        ...        ...
# 455  0.377117          1
# 456 -0.752175          1
# 457 -0.839043          1
# 458 -0.839043          1
# 459  2.288227          0
#
# [460 rows x 12 columns],      quality
# 0        0.7
# 1        0.5
# 2        0.5
# 3        0.5
# 4        0.6
# ..       ...
# 455      0.7
# 456      0.5
# 457      0.5
# 458      0.5
# 459      0.7
#
# [460 rows x 1 columns]), (      fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0         -0
#
#      free sulfur dioxide  total sulfur dioxide   density        pH  sulphates  \
# 0               0.025477              1.184150  0.910015 -0.661382  -0.443922
# 1               3.007302              1.366740 -0.303884 -1.628412  -0.865549
# 2              -0.089209              0.254597 -0.482398 -2.414124  -0.745084
# 3              -0.719980             -0.874146  0.588689  1.151800   0.158404
# 4              -1.121379              0.072006 -0.396711 -0.540503  -0.443922
# ..                   ...                   ...       ...       ...        ...
# 454             0.426876             -0.293176  0.517283  0.910042   0.037939
# 455            -0.375923             -0.575362  1.338450 -0.419624  -0.082526
# 456            -0.089209             -0.392771  0.074567  0.910042  -0.263224
# 457             0.828276             -0.492366  0.910015  2.118830   1.423288
# 458            -0.490608             -1.139733 -0.414563 -0.056988   0.760730
#
#       alcohol  wine_type
# 0   -1.447124          0
# 1   -0.057226          0
# 2   -0.839043          0
# 3   -1.186518          1
# 4   -1.012781          0
# ..        ...        ...
# 454 -0.839043          1
# 455 -0.317832          1
# 456 -0.317832          1
# 457 -0.491569          1
# 458  0.811460          1
#
# [459 rows x 12 columns],      quality
# 0        0.6
# 1        0.7
# 2        0.5
# 3        0.5
# 4        0.5
# ..       ...
# 454      0.6
# 455      0.6
# 456      0.6
# 457      0.5
# 458      0.8
#
# [459 rows x 1 columns]), (      fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0         -0.429384         -1.000274     1.128402       -0.738274  -0.605858
# 1         -1.010941         -0.582475     0.645714        1.564600  -0.442967
# 2         -0.041680          0.618698     0.585377       -0.542284  -0.163726
# 3         -1.010941         -0.321351     2.154115        2.814031  -0.489508
# 4         -1.269410          1.349847    -1.828065       -0.542284   0.464568
# ...             ...               ...          ...             ...        ...
# 1833       0.475260          1.297622    -1.224704       -0.370794   0.511109
# 1834       0.022938         -1.209174    -0.198991        0.045683  -0.396427
# 1835      -0.106297         -0.216901    -0.017983       -0.640279   0.162056
# 1836      -0.170914         -1.104724    -0.198991        2.324058  -0.233536
# 1837      -1.075558         -0.425800    -0.138655        0.070182  -0.652399
#
#       free sulfur dioxide  total sulfur dioxide   density        pH  \
# 0               -0.605294              1.184150 -0.946536  0.003451
# 1                1.688418              0.935162 -0.589507 -0.963579
# 2               -0.777322             -1.206130 -0.218197  0.063891
# 3                0.025477              1.184150  0.910015 -0.661382
# 4               -1.293407             -1.355522 -0.560945  2.783663
# ...                   ...                   ...       ...       ...
# 1833            -0.490608             -0.874146  0.956429  0.245209
# 1834            -0.146552              0.088605 -0.403852 -1.024018
# 1835            -0.490608             -1.139733 -0.414563 -0.056988
# 1836             1.114990              1.034757  0.970710 -1.870170
# 1837             0.484219              0.022208 -2.039045 -0.177867
#
#       sulphates   alcohol  wine_type
# 0      0.339102  0.463986          0
# 1      0.098172  0.463986          0
# 2      0.399334  1.158935          1
# 3     -0.443922 -1.447124          0
# 4      0.339102  2.027621          1
# ...         ...       ...        ...
# 1833  -0.142759 -0.839043          1
# 1834  -0.624619 -0.839043          0
# 1835   0.760730  0.811460          1
# 1836  -0.986015 -1.447124          0
# 1837  -0.022294  2.288227          0
#
# [1838 rows x 12 columns],       quality
# 0         0.5
# 1         0.7
# 2         0.6
# 3         0.6
# 4         0.7
# ...       ...
# 1833      0.5
# 1834      0.6
# 1835      0.8
# 1836      0.8
# 1837      0.7
#
# [1838 rows x 1 columns],      fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0        -0.687854         -0.582475    -0.017983        1.160372  -0.373157
# 1        -0.235532         -1.052499     0.042353        1.368611  -0.303346
# 2         0.346025          0.827598    -0.138655       -0.664778   7.003479
# 3         2.090695         -0.739150     0.887058       -0.272799  -0.163726
# 4        -0.752471         -0.686925    -0.802352        0.976632  -0.536048
# ..             ...               ...          ...             ...        ...
# 454      -0.623236         -0.321351    -0.742016        0.486659   0.348218
# 455      -0.235532          1.219285    -1.405713       -0.444290   0.231867
# 456      -0.817088         -0.895825    -0.561008        0.168177  -0.745479
# 457      -0.429384         -1.104724     0.283697        2.226063  -0.675669
# 458      -1.592497         -0.478025    -0.017983       -0.860767  -0.698939
#
#      free sulfur dioxide  total sulfur dioxide   density        pH  sulphates  \
# 0              -0.031866              1.217348 -0.700186 -0.056988  -0.082526
# 1               1.344361              1.200749  0.588689  0.910042  -0.925782
# 2              -0.547951             -0.608560  0.517283 -0.842700   4.254218
# 3              -0.318580             -0.724754  0.660095 -0.721821  -0.202991
# 4               1.975132              1.748521  0.153114 -0.238306  -0.624619
# ..                   ...                   ...       ...       ...        ...
# 454             1.229676              2.445686  0.624392  1.030921  -0.564387
# 455            -0.547951             -0.110585  0.760063  1.574875  -0.202991
# 456             0.197505              0.818968 -0.410992  0.668285  -1.467875
# 457             1.344361              0.420588  0.038864 -1.507533   0.339102
# 458             0.140162              0.984960 -1.196456  1.756194  -0.082526
#
#       alcohol  wine_type
# 0    0.768026          0
# 1   -0.491569          0
# 2   -1.012781          1
# 3   -0.752175          1
# 4   -0.925912          0
# ..        ...        ...
# 454 -1.099649          0
# 455 -0.665306          1
# 456 -0.317832          0
# 457  0.203380          0
# 458 -0.317832          0
#
# [459 rows x 12 columns],      quality
# 0        0.6
# 1        0.6
# 2        0.5
# 3        0.5
# 4        0.5
# ..       ...
# 454      0.5
# 455      0.5
# 456      0.7
# 457      0.6
# 458      0.6
#
# [459 rows x 1 columns])]

# %% [markdown]
# ## Linear Regression (26pts)
#
# Use linear regression to prediction `quality`.

# %%
# 3pts
def mean_square_error_loss(pred: np.ndarray, target: np.ndarray):
    # Normalized by pred.shape[0]

    # ========== YOUR CODE STARTS HERE ==========
    return np.sum((pred - target) ** 2) / pred.shape[0]
    # ========== YOUR CODE ENDS HERE ============


# 5pts
def mse_gradient(X: np.ndarray, target: np.ndarray, theta: np.ndarray):
    # ========== YOUR CODE STARTS HERE ==========
    n = X.shape[0]
    pred = X @ theta
    return (2 / n) * X.T @ (pred - target)
    # ========== YOUR CODE ENDS HERE ============

# %%
theta_dummy = np.linspace(1, -1, 64)
x_dummy = np.ones((8, 64))
pred_dummy = x_dummy @ theta_dummy
target_dummy =  np.linspace(1, 0, 8)
print("Dummy Loss:", mean_square_error_loss(pred_dummy, target_dummy))
print("Dummy Gradient Mean & STD:", mse_gradient(x_dummy, target_dummy, theta_dummy).mean(), mse_gradient(x_dummy, target_dummy, theta_dummy).std())
# Out:
# Dummy Loss: 0.35714285714285343
# Dummy Gradient Mean & STD: -0.9999999999999927 2.220446049250313e-16

# %% [markdown]
# ### Hyper-Parameters Tuning (6pts)
#
# You need to reach an averaged final MSE < 0.05 on 5-fold validation sets to get points for this part.

# %%
# ========== YOUR CODE STARTS HERE ==========
num_epochs = 10000
learning_rate = 0.01
# ========== YOUR CODE ENDS HERE ============

# %% [markdown]
# ### Training (10pts)
#
# Hint: A convenient way to calculate $X \cdot \theta$ is to prepend a column of 1's to your $X$ matrix so that you don't have to perform an extra addition operation for the bias.
#
# If you decide to use this implementation, add an additional dimension to your feature matrix so that they are consistent in shape. See the image below for illustration. See this [illustration](https://cs231n.github.io/linear-classify/#:~:text=Illustration%20of%20the,and%20the%20biases.) for more detail.
#
# You report should include the train, val and test loss. You can try different learning rates and epoch combinations and report the best results you get based on the validation loss.

# %%
train_losses_folds = [[] for _ in range(K)]
val_losses_folds = [[] for _ in range(K)]

thetas = []

for i in range(K):
    x_train, y_train, x_val, y_val = train_val_list[i]

    y_train = y_train["quality"]
    y_val = y_val["quality"]

    # Translate pd.DataFrame to numpy (3pt)
    # ========== YOUR CODE STARTS HERE ==========
    X_train = np.hstack([np.ones((x_train.shape[0], 1)), x_train.to_numpy()])
    X_val = np.hstack([np.ones((x_val.shape[0], 1)), x_val.to_numpy()])
    Y_train = y_train.to_numpy()
    Y_val = y_val.to_numpy()
    # ========== YOUR CODE ENDS HERE ============

    # Initialize theta (1pt)
    # ========== YOUR CODE STARTS HERE ==========
    theta = np.zeros(X_train.shape[1])
    # ========== YOUR CODE ENDS HERE ============

    for epoch in trange(num_epochs, desc="Epoch"):
        # Compute loss, and save to train_losses_folds and val_losses_folds (3pts)
        # ========== YOUR CODE STARTS HERE ==========
        train_pred = X_train @ theta
        val_pred = X_val @ theta
        train_losses_folds[i].append(mean_square_error_loss(train_pred, Y_train))
        val_losses_folds[i].append(mean_square_error_loss(val_pred, Y_val))
        # ========== YOUR CODE ENDS HERE ============

        # Gradient descent (3pts)
        # ========== YOUR CODE STARTS HERE ==========
        grad = mse_gradient(X_train, Y_train, theta)
        theta = theta - learning_rate * grad
        # ========== YOUR CODE ENDS HERE ============

    # Save trained theta
    thetas.append(theta)
# Out:
# Epoch:   0%|          | 0/10000 [00:00<?, ?it/s]
# Epoch:   0%|          | 0/10000 [00:00<?, ?it/s]
# Epoch:   0%|          | 0/10000 [00:00<?, ?it/s]
# Epoch:   0%|          | 0/10000 [00:00<?, ?it/s]
# Epoch:   0%|          | 0/10000 [00:00<?, ?it/s]

# %%
print(f"Averaged final training loss: {sum([train_losses[-1] for train_losses in train_losses_folds]) / len(train_losses_folds)}")
print(f"Averaged final validation loss: {sum([val_losses[-1] for val_losses in val_losses_folds]) / len(val_losses_folds)}")

plt.plot(np.arange(num_epochs), train_losses_folds[0], label="Train loss")
plt.plot(np.arange(num_epochs), val_losses_folds[0], label="Val loss")
plt.title("Train + validation loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.show()
# Out:
# Averaged final training loss: 0.005031111034632651
# Averaged final validation loss: 0.005138048504732836

# %% [markdown]
# ### Evaluation on Test Set (3pts)
#
# Average the predictions from thetas from each fold as the final prediction

# %%
def inference_final(x_test, thetas):
    # ========== YOUR CODE STARTS HERE ==========
    X_test = np.hstack([np.ones((x_test.shape[0], 1)), x_test.to_numpy()])
    preds = np.array([X_test @ theta for theta in thetas])
    return preds.mean(axis=0)
    # ========== YOUR CODE ENDS HERE ============


test_pred = inference_final(x_test, thetas)
test_loss = mean_square_error_loss(test_pred, y_test["quality"])
print(f"Test loss: {test_loss}")
# Out:
# Test loss: 0.004940177465430717
